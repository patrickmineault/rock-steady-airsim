# %%
import tables

f = tables.open_file('../data/raw/nh/2021-02-01T144310/output.h5', 'r')

# %%
import matplotlib.pyplot as plt
import numpy as np

data = f.get_node('/depth')[:]
print(data.shape)
plt.imshow(np.log(data[2, :, :]))
# Out:
# (38, 112, 112)

# %%
import matplotlib.pyplot as plt
import numpy as np

data = f.get_node('/videos')[:]
data.shape
#plt.imshow((data[0, 0, :, :, :].astype(np.float) - 
#            data[0, 1, :, :, :].astype(np.float)).transpose((1, 2, 0)))
#data.max()
plt.imshow(np.diff(data[1, ...].astype(np.float), axis=0)[0, :, :, :].transpose(1, 2, 0) * .002 + .5)

# %%
plt.imshow(data[1, 2, :, :, :].transpose((1, 2, 0)))
